# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import pandas as pd

import os
from pprint import pprint

# %% [markdown]
# Codeup Blog Articles
#
# Visit Codeup's Blog and record the urls for at least 5 distinct blog posts. For each post, you should scrape at least the post's title and content.
#
# Encapsulate your work in a function named get_blog_articles that will return a list of dictionaries, with each dictionary representing one article. The shape of each dictionary should look like this:

# %%
{
    'title': 'the title of the article',
    'content': 'the full text content of the article'
}
# Out:
# {'title': 'the title of the article',
#  'content': 'the full text content of the article'}

# %% [markdown]
# post 1: https://codeup.com/featured/women-in-tech-panelist-spotlight/
# post 2: https://codeup.com/featured/women-in-tech-rachel-robbins-mayhill/
# post 3: https://codeup.com/codeup-news/women-in-tech-panelist-spotlight-sarah-mellor/
# post 4: https://codeup.com/featured/apida-heritage-month/
# post 5: https://codeup.com/codeup-news/panelist-spotlight-4/

# %%
#Attempt 1 at problem 1, following step 2 from notes

url = 'https://codeup.com/'
#ouput was "<Response [403]>"" aka forbidden, so I need to change my user-agent so that I can get "Response [200]"
response = get(url)
response
# Out:
# <Response [403]>

# %%
#to remedy Reponse [403] output continuing guidance from step 2 on problem 1

requests.utils.default_headers()
# Out:
# {'User-Agent': 'python-requests/2.28.1', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
#where did you gt the "Chrome/91.0.4472.124"
headers ={"User-Agent": "Chrome/91.0.4472.124"}
response  = get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
#step 4

pprint(response.text[:400])
# Out:
# ('<!DOCTYPE html>\n'
#  '<html lang="en-US">\n'
#  '<head>\n'
#  '\t<meta charset="UTF-8" />\n'
#  '<meta http-equiv="X-UA-Compatible" content="IE=edge">\n'
#  '\t<link rel="pingback" href="https://codeup.com/xmlrpc.php" />\n'
#  '\n'
#  '\t<script type="text/javascript">\n'
#  "\t\tdocument.documentElement.className = 'js';\n"
#  '\t</script>\n'
#  '\t\n'
#  '\t<link rel="preconnect" href="https://fonts.gstatic.com" crossorigin '
#  '/><script id="diviarea-loader">window.DiviPopupData=wi')

# %%
#step 5

pprint(response.content)
# Out:
# (b'<!DOCTYPE html>\n<html lang="en-US">\n<head>\n\t<meta charset="UTF-8" />'
#  b'\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t<link rel="pingb'
#  b'ack" href="https://codeup.com/xmlrpc.php" />\n\n\t<script type="text/javasc'
#  b'ript">\n\t\tdocument.documentElement.className = \'js\';\n\t</script>\n\t'
#  b'\n\t<link rel="preconnect" href="https://fonts.gstatic.com" crossorigin />'
#  b'<script id="diviarea-loader">window.DiviPopupData=window.DiviAreaConfig={"zI'
#  b'ndex":1000000,"animateSpeed":400,"triggerClassPrefix":"show-popup-","idAttri'
#  b'b":"data-popup","modalIndicatorClass":"is-modal","blockingIndicatorClass":"i'
#  b's-blocking","defaultShowCloseButton":true,"withCloseClass":"with-close","noC'
#  b'loseClass":"no-close","triggerCloseClass":"close","singletonClass":"single",'
#  b'"darkModeClass":"dark","noShadowClass":"no-shadow","altCloseClass":"close-al'
#  b't","popupSelector":".et_pb_section.popup","initializeOnEvent":"et_pb_after_i'
# ...

# %%
#step 6
#.parser allows me to break "content" up into it's parts 

soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://codeup.com/xmlrpc.php" rel="pingback"/>
# <script type="text/javascript">
# 		document.documentElement.className = 'js';
# 	</script>
# ...

# %%
#for header

soup.h1
# Out:
# <h1>Launch Your Career <span style="color: #4e5e33;">in tech.</span></h1>

# %%
#for title

soup.h1.text
# Out:
# 'Launch Your Career in tech.'

# %%
#all paragraph elements

soup.find_all('p')
# Out:
# [<p>Go from no experience to tech professional in less than 6 months.</p>,
#  <p style="text-align: center;">Always dreamed of coding games, apps, or websites? Develop the applications every company needs.</p>,
#  <p>Do you love data and details? Become the business analyst that identifies actionable insights.</p>,
#  <p>Coding &amp; Statistics aren’t your thing? Anyone who likes to fix and build things will love this program.</p>,
#  <p><span style="font-weight: 400;">Start a tech career where room for growth is limitless and your skillset is always needed. Imagine working for one of our many employer partners, including…</span></p>,
#  <p>Are you a hiring manager looking to hire tech talent? Get connected with pre-vetted and diverse candidates with zero placement fees and a salary refund guarantee. Just tell us about the tech talent you need and we’ll handpick candidates just for you.</p>,
# ...

# %%
codeup_soup = requests.get('https://codeup.com/')
codeup_soup
# Out:
# <Response [403]>

# %%
headers ={"User-Agent": "Chrome/109.0.0.0"}
response  = get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
def get_blog_articles(url):
    headers ={"User-Agent": "Chrome/109.0.0.0"}
    response = get(url, headers=headers)
    if response.status_code == '200':
        title = soup.h1.text
        content = soup.find_all('p')
        return title, content
    else:
            return None, None

# %%
url_list = ['https://codeup.com/featured/women-in-tech-panelist-spotlight/', 'https://codeup.com/featured/women-in-tech-rachel-robbins-mayhill/', 
       'https://codeup.com/codeup-news/women-in-tech-panelist-spotlight-sarah-mellor/', 'https://codeup.com/featured/apida-heritage-month/', 
      'https://codeup.com/codeup-news/panelist-spotlight-4/']

# %%
url = 'https://codeup.com/featured/women-in-tech-panelist-spotlight/'

# %%
def get_blog_articles(url):
    headers ={"User-Agent": "Chrome/109.0.0.0"}
    response = get(url, headers=headers)
    if response.status_code == '200':
        title = soup.h1.text
        content = soup.find_all('p')
        return title, content
    else:
            return None, None 

for url in url_list:
    title, content = get_blog_articles(url) 
    if title and content:
        print('Title:', title) 
        print('Content:', content)
    else:
        print("Nonya")
# Out:
# Nonya
# Nonya
# Nonya
# Nonya
# Nonya

# %% [markdown]
# *above is initial attempt code
# *below is final code,
# Mistakes made:
#     1. Response code is an integer not a string, so no quotes needed
#     2. Didn't have the html.parser in function
#     3. soup.find_all('p') was correct

# %%
def get_blog_articles(url):
    headers = {"User-Agent": "Chrome/109.0.0.0"}
    response = get(url, headers=headers)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        title = soup.find('h1').text if soup.find('h1') else None
        content = [p.text for p in soup.find_all('p')]
        
        return title, content
    else:
        return None, None

url_list = [
    'https://codeup.com/featured/women-in-tech-panelist-spotlight/',
    'https://codeup.com/featured/women-in-tech-rachel-robbins-mayhill/',
    'https://codeup.com/codeup-news/women-in-tech-panelist-spotlight-sarah-mellor/',
    'https://codeup.com/featured/apida-heritage-month/',
    'https://codeup.com/codeup-news/panelist-spotlight-4/'
]

for url in url_list:
    title, content = get_blog_articles(url)
    
    if title and content:
        print('Title:', title)
        print('Content:', content)
        print('---')
    else:
        print('Failed to retrieve title and content from the blog article.')
# Out:
# Title: Women in tech: Panelist Spotlight – Magdalena Rahn
# ...

# %% [markdown]
# Steps to solution:
#
# 1. define headers *headers = {'User-Agent:...'}*
# 2. Scrape blog homepage
# 3. created href list
# 4. extract links from href list/link_list created
# 5. Make a request "response =..." without BS
# 6. BeautifulSoup, "soup = BeautifulSoup(response.content, 'html.parser')
# 7. Find components you want:
#
#     - title = soup.find('h1'), and "title.text" will clean it up
#     - x = soup.find(location in inspector, class name), eg. for date
#         pdate = soup.find('span', class_="published")
#
# 8. create 'for loop' to loop thorugh the link to collect all of the article's info
#
# headers = {'User-Agent': 'Codeup Data Science'}
# article_info = []
#
# #from line 4
# for link in links_list:
# #from line 1
#      response = get(link, headers=headers)
#      #from line 6
#      soup = BeautifulSoup(reponse.content, 'html.parser')
#
#     link_dict = {#create dictionary from code from line 7}
#
# 9. Create def function:
#
# def x(created list):
#      """
#
#
#      """
#      file = "blog_posts.json"
#
#      if os.path.exists(file):
#           with open(file) as f
#               return json.load(f)
#      -line 1
#      #blank list
#      article_info = []
#      -for loop
#      article_info.append(info_dict)
#
#      with open(file, "w") as f:
#           json.dump(article_info, f)
#      return article_info
#
# 10. test
#
# article_info =

# %%
article_info = []

for link in links_list:
    response = get(link, headers=headers)

# %% [markdown]
# 2.
#
# News Articles
#
# We will now be scraping text data from inshorts, a website that provides a brief overview of many different topics.
#
# Write a function that scrapes the news articles for the following topics:
#
#     Business
#
#     Sports
#
#     Technology
#
#     Entertainment
#
#     The end product of this should be a function named get_news_articles that returns a list of dictionaries, where each dictionary has this shape:

# %%
url_list = ['', '', '']

# %%
#checking for "Response [200]", got it on my first go, no need for headers(?)
url = 'https://inshorts.com/en/read/technology'
response = get(url)
response
# Out:
# <Response [200]>

# %%
#allows us to parse/separate and identifify components of this

soup_news = BeautifulSoup(response.content, 'html.parser')
soup_news
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>
#     /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
# ...

# %%
soup_news.li
# Out:
# <li class="active-category">All News</li>

# %%
def scrape_inshorts():
    url = 'https://inshorts.com/en/read'
    response = get(url, headers=headers)

    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        articles = soup.find_all('div', class_='news-card')
        
        for article in articles:
            # Extract title
            title = article.find('span', itemprop='headline').text.strip()
            
            # Extract content
            content = article.find('div', itemprop='articleBody').text.strip()
            
            # Extract category
            category = article.find('a', class_='clickable').text.strip()
            
            # Print the extracted information
            print('Title:', title)
            print('Content:', content)
            print('Category:', category)
            print('---')
    else:
        print('Failed to retrieve data from the Inshorts website.')

scrape_inshorts()
"""In this example, we target the news-card class, which represents each news article on the Inshorts website. Inside the loop, we extract the title, content, and category by using appropriate CSS selectors and methods provided by BeautifulSoup.

Please note that web scraping can be subject to changes in website structure and terms of service. Make sure to review the website's terms of service before scraping and consider the website's policies on data usage and scraping.






Regenerate response"""
# Out:
# Title: PM Modi addresses Yoga Day event at UN HQ, says 'Yoga is free from copyrights'
# Content: PM Narendra Modi on Wednesday addressed the International Yoga Day event at UN Headquarters in New York. He said, "Yoga comes from India and it's a very old tradition. Yoga is free from copyrights, patents and...royalty payments." He added, "Yoga is adaptable to your age, gender and fitness level. [It] is portable and...truly universal."
# Category: PM Modi addresses Yoga Day event at UN HQ, says 'Yoga is free from copyrights'
# ---
# Title: 'Jalegi tere baap ki' dialogue revised in 'Adipurush', video shows new dialogue
# Content: 'Adipurush' makers have revised Lord Hanuman's dialogue "Jalegi tere baap ki" after criticism. The word "baap" has been replaced with the word "Lanka". In a clip released online, Lord Hanuman tells Indrajeet, "Kapda teri Lanka ka, tel teri Lanka ka, aag bhi teri Lanka ki, jalegi bhi teri Lanka hi."
# ...

# %% [markdown]
# Steps to solution:
#
# 1. define headers *headers = {'User-Agent:...'}* #no need since it done already
# 2. Scrape homepage
#     find necessary components
#         1. can do this by finding component you want
#         2. hover over desired component and inspect
#         3. continue to narrow down
#     get summaries
#     base url
# 3. created href list
# 4. extract links from href list/link_list created
# 5. Make a request "response =..." without BS
#     .text can only be used on
# 6. BeautifulSoup, "soup = BeautifulSoup(response.content, 'html.parser')
# 7. Find components you want:
#
#     - title = soup.find('h1'), and "title.text" will clean it up
#     - x = soup.find(location in inspector, class name), eg. for date
#         pdate = soup.find('span', class_="published")
#
# 8. create 'for loop' to loop thorugh the link to collect all of the article's info
#
# headers = {'User-Agent': 'Codeup Data Science'}
# article_info = []
#
# #from line 4
# for link in links_list:
# #from line 1
#      response = get(link, headers=headers)
#      #from line 6
#     soup = BeautifulSoup(reponse.content, 'html.parser')
#
#     link_dict = {#create dictionary from code from line 7}
#
# 9. Create def function:
#
# def x(created list):
#      """
#
#
#      """
#      file = "blog_posts.json"
#
#      if os.path.exists(file):
#           with open(file) as f
#               return json.load(f)
#      -line 1
#      #blank list
#      article_info = []
#      -for loop
#      article_info.append(info_dict)
#
#      with open(file, "w") as f:
#           json.dump(article_info, f)
#      return article_info
#
# 10. test
#
# article_info =

# %%
url_news_list = ['https://inshorts.com/en/read/business', 'https://inshorts.com/en/read/sports',
                'https://inshorts.com/en/read/technology', 'https://inshorts.com/en/read/entertainment']

# %%
def get_news_articles(url):
# Out:
#   Input In [25]
#
#     ^
# IndentationError: expected an indented block
