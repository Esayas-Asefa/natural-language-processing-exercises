# %%
import unicodedata
import re
import json
from bs4 import BeautifulSoup

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

import pandas as pd

import acquire as acq

# %% [markdown]
# Define a function named basic_clean. It should take in a string and apply some basic text cleaning to it:
#
# Lowercase everything
# Normalize unicode characters
# Replace anything that is not a letter, number, whitespace or a single quote.

# %% [markdown]
# 1. lowercase text
#     take original article and x = a.lower()
# 2. remove accented and non-ASCII characters
#     use new function called unicodedata, must import by same name
#     in use unicoddata.normalize('NFKC', article).encode('ascii', 'ignore') #<-normalizes than continue \ .encode(ascii, 'ignore') \ .decode('utf-8') #turning back to a string
#     #NFKD -- changes it to its normal equivalent vs NFKC -- just dropping different ones
# 3. remove special characters
#     use regex, use sub x = re.sub(r'[anything you don't want removed]', 'what you want it replaced with', 'media piece')
# 4. tokenize the strings into discrete units (tokenize means? breaks things up into components and makes them their own thing?)
#     new import: import nltk
#     create tokenizer
#         tokenize = nltk.tokenize.ToktokTokinizer()
#     use tokenizer
#         tokenize.tokenize(article, return_str=True)
# 5. stem/lemmatize words -- will treat the
#     split the original texxt
#     stems = [ps.stem(word) for word in article.split()]
#     stems[:10]
#     [ps.word.upper() for word in article.split()]
#     create porter
#     x = nltk.porter.PorterStemmer()
#     test stemmer
#     join words back together
# 6. remove stopwords
#     parse/split
#     create list
#     create call
#         filtered = [word for word in words if word not in stopwords_ls]
#     join

# %%
def basic_clean(text):
    text = text.lower()
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8')
    text = re.sub(r'[^a-z0-9\'\s]', '', text)
    return text

# %% [markdown]
# Define a function named tokenize. It should take in a string and tokenize all the words in the string.

# %% [markdown]
# 1. lowercase text
#     take original article and x = a.lower()
# 2. remove accented and non-ASCII characters
#     use new function called unicodedata, must import by same name
#     in use unicoddata.normalize('NFKC', article).encode('ascii', 'ignore') #<-normalizes than continue \ .encode(ascii, 'ignore') \ .decode('utf-8') #turning back to a string
#     #NFKD -- changes it to its normal equivalent vs NFKC -- just dropping different ones
# 3. remove special characters
#     use regex, use sub x = re.sub(r'[anything you don't want removed]', 'what you want it replaced with', 'media piece')
# 4. tokenize the strings into discrete units (tokenize means? breaks things up into components and makes them their own thing?)
#     new import: import nltk
#     create tokenizer
#         tokenize = nltk.tokenize.ToktokTokinizer()
#     use tokenizer
#         tokenize.tokenize(article, return_str=True)
# 5. stem/lemmatize words -- will treat the
#     split the original texxt
#     stems = [ps.stem(word) for word in article.split()]
#     stems[:10]
#     [ps.word.upper() for word in article.split()]
#     create porter
#     x = nltk.porter.PorterStemmer()
#     test stemmer
#     join words back together
# 6. remove stopwords
#     parse/split
#     create list
#     create call
#         filtered = [word for word in words if word not in stopwords_ls]
#     join

# %%
def tokenize(text):
    tokenize = nltk.tokenize.ToktokTokenizer()
    text = tokenize.tokenize(text, return_str=True)
    return text

# %% [markdown]
# Define a function named stem. It should accept some text and return the text after applying stemming to all the words.

# %%
def stem(text):
    ps = nltk.porter.PorterStemmer()
    stems = [ps.stem(word) for word in text.split()]
    text = ' '.join(stems)
    return text

# %% [markdown]
# Define a function named lemmatize. It should accept some text and return the text after applying lemmatization to each word.m

# %%
def lemmatize(text):
    nltk.download('all')
    wn1 = nltk.stem.WordNetLemmatizer()
    lemmas = [wn1.lemmatize(word) for word in text.split()]
    text_lemma = ' '.join(lemmas)
    return text

# %% [markdown]
# Define a function named remove_stopwords. It should accept some text and return the text after removing all the stopwords.
#
# This function should define two optional parameters, extra_words and exclude_words. These parameters should define any additional stop words to include, and any words that we don't want to remove.

# %%
#mine, failed to add ', extra_words=[], exclude_words=[]'
def remove_stopwords(text, extra_words=[], exclude_words=[]):
    #nltk.download('stopwords')
    stopwords_ls = stopwords.words('english')
    stopwords_ls.extend(extra_words)
    #to add words to stopwords_ls.append('word(s) here')
    words = text.split()
    stopword_list = [word for word in words if word not in stopwords_ls]
    filtered_words = [word for word in words if word not in stopwords_ls]
    return ' '.join(text)

# %% [markdown]
# #Andy's
# def remove_stopwords(text, extra_words=[], exclude_words=[]):
#     # Remove stopwords from the text
#     stopword_list = stopwords.words('english')
#     stopword_list.extend(extra_words)
#     stopword_list = [word for word in stopword_list if word not in exclude_words]
#     words = text.split()
#     filtered_words = [word for word in words if word not in stopword_list]
#     return ' '.join(filtered_words)

# %% [markdown]
# Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe news_df.

# %% [markdown]
# Make another dataframe for the Codeup blog posts. Name the dataframe codeup_df.

# %%
url = "https://codeup.com/blog/"
'''article_info = [
    'https://codeup.com/featured/women-in-tech-panelist-spotlight/',
    'https://codeup.com/featured/women-in-tech-rachel-robbins-mayhill/',
    'https://codeup.com/codeup-news/women-in-tech-panelist-spotlight-sarah-mellor/',
    'https://codeup.com/featured/apida-heritage-month/',
    'https://codeup.com/codeup-news/panelist-spotlight-4/'
]'''

codeup_df = acq.get_all_articles(url)

# %%
codeup_df
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
# 5  Black Excellence in Tech: Panelist Spotlight –...
#
#                                              content
# 0  May is traditionally known as Asian American a...
# 1  Codeup is hosting a Women in Tech Panel in hon...
# 2  Codeup is hosting a Women in Tech Panel in hon...
# 3  Codeup is hosting a Women in Tech Panel in hon...
# 4  Codeup is hosting a Women in Tech Panel in hon...
# 5   Codeup is hosting a Black Excellence in Tech ...

# %%
codeup_df['clean'] = codeup_df['content'].apply(basic_clean)

# %%
codeup_df
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
# 5  Black Excellence in Tech: Panelist Spotlight –...
#
#                                              content  \
# 0  May is traditionally known as Asian American a...
# 1  Codeup is hosting a Women in Tech Panel in hon...
# 2  Codeup is hosting a Women in Tech Panel in hon...
# 3  Codeup is hosting a Women in Tech Panel in hon...
# 4  Codeup is hosting a Women in Tech Panel in hon...
# 5   Codeup is hosting a Black Excellence in Tech ...
#
#                                                clean
# 0  may is traditionally known as asian american a...
# 1  codeup is hosting a women in tech panel in hon...
# 2  codeup is hosting a women in tech panel in hon...
# ...

# %%
codeup_df['clean'] = codeup_df['clean'].apply(tokenize)

# %%
codeup_df['clean'] = codeup_df['clean'].apply(remove_stopwords)

# %%
codeup_df
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
# 5  Black Excellence in Tech: Panelist Spotlight –...
#
#                                              content  \
# 0  May is traditionally known as Asian American a...
# 1  Codeup is hosting a Women in Tech Panel in hon...
# 2  Codeup is hosting a Women in Tech Panel in hon...
# 3  Codeup is hosting a Women in Tech Panel in hon...
# 4  Codeup is hosting a Women in Tech Panel in hon...
# 5   Codeup is hosting a Black Excellence in Tech ...
#
#                                                clean
# 0  m a y   i s   t r a d i t i o n a l l y   k n ...
# 1  c o d e u p   i s   h o s t i n g   a   w o m ...
# 2  c o d e u p   i s   h o s t i n g   a   w o m ...
# ...

# %%
codeup_df['stem'] = codeup_df['clean'].apply(stem)

# %%
codeup_df
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
# 5  Black Excellence in Tech: Panelist Spotlight –...
#
#                                              content  \
# 0  May is traditionally known as Asian American a...
# 1  Codeup is hosting a Women in Tech Panel in hon...
# 2  Codeup is hosting a Women in Tech Panel in hon...
# 3  Codeup is hosting a Women in Tech Panel in hon...
# 4  Codeup is hosting a Women in Tech Panel in hon...
# 5   Codeup is hosting a Black Excellence in Tech ...
#
#                                                clean  \
# 0  m a y   i s   t r a d i t i o n a l l y   k n ...
# 1  c o d e u p   i s   h o s t i n g   a   w o m ...
# ...

# %%
codeup_df['lem'] = codeup_df['clean'].apply(lemmatize)
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/esayasa./nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/esayasa./nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/esayasa./nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/esayasa./nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/esayasa./nltk_data...
# ...

# %%
codeup_df
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
# 5  Black Excellence in Tech: Panelist Spotlight –...
#
#                                              content  \
# 0  May is traditionally known as Asian American a...
# 1  Codeup is hosting a Women in Tech Panel in hon...
# 2  Codeup is hosting a Women in Tech Panel in hon...
# 3  Codeup is hosting a Women in Tech Panel in hon...
# 4  Codeup is hosting a Women in Tech Panel in hon...
# 5   Codeup is hosting a Black Excellence in Tech ...
#
#                                                clean  \
# 0  m a y   i s   t r a d i t i o n a l l y   k n ...
# 1  c o d e u p   i s   h o s t i n g   a   w o m ...
# ...

# %% [markdown]
# For each dataframe, produce the following columns:
#
#  - title to hold the title
#  - original to hold the original article/post content
#  - clean to hold the normalized and tokenized original with the stopwords removed.
#  - stemmed to hold the stemmed version of the cleaned data.
#  - lemmatized to hold the lemmatized version of the cleaned data.

# %%
news_df = news_df.rename(columns={'content':'original'}).drop(columns='category')
news_df.head()

# %%
news_df['stem'] = news_df.clean.apply(stem)
news_df['lemma'] = news_df.clean.apply(lemmatize)

# %%
def clean_df(df, extra_words=[], exclude_words=[]):
    """
    Send in df with columns: title and original,
    returns df with original, clean, stemmed, and lemmatized data
    """
    df['clean'] = df.original\
                        .apply(basic_clean)\
                        .apply(tokenize)\
                        .apply(remove_stopwords, 
                                    extra_words=extra_words,
                                    exclude_words=exclude_words)
    df['stemmed'] = df.clean.apply(stem)
    df['lemmatized'] = df.clean.apply(lemmatize)
    
    return df

# %%
codeup_df = pd.DataFrame(blogs)

# %%
codeup_df = codeup_df.rename(columns={'content':'original'}).drop(columns='date_published')

# %%
clean_df(codeup_df)

# %% [markdown]
# Ask yourself:
#
#  - If your corpus is 493KB, would you prefer to use stemmed or lemmatized text?
#
#  lemmatized
#
#  - If your corpus is 25MB, would you prefer to use stemmed or lemmatized text?
#
#  stemmed
#
#  - If your corpus is 200TB of text and you're charged by the megabyte for your hosted computational resources, would you prefer to use stemmed or lemmatized text?
#
# lemmatized
